# %%
# %%writefile requirements.txt
# fastapi
# uvicorn
# sqlalchemy
# python-dotenv
# aiofiles
# jinja2
# Out:
# Writing requirements.txt

# %%
# %%writefile Procfile
# web: uvicorn main:app --host 0.0.0.0 --port $PORT
# Out:
# Writing Procfile
